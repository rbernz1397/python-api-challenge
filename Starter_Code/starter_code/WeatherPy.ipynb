# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + f'q={city}&appid={weather_api_key}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port hedland
# Processing Record 2 of Set 1 | papatowai
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | zalingei
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 8 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 9 of Set 1 | ancud
# Processing Record 10 of Set 1 | soio
# Processing Record 11 of Set 1 | stanley
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | mermoz boabab
# Processing Record 14 of Set 1 | iskateley
# Processing Record 15 of Set 1 | nagqu
# Processing Record 16 of Set 1 | wailua homesteads
# Processing Record 17 of Set 1 | kapuskasing
# Processing Record 18 of Set 1 | dawei
# Processing Record 19 of Set 1 | dembi dolo
# Processing Record 20 of Set 1 | fale old settlement
# Processing Record 21 of Set 1 | keflavik
# Processing Record 22 of Set 1 | labrador city
# Processing Record 23 of Set 1 | polyarnyy
# Processing Record 24 of Set 1 | itamaraca
# Processing Record 25 of Set 1 | port mathurin
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | dholka
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | la ronge
# Processing Record 30 of Set 1 | puerto natales
# Processing Record 31 of Set 1 | suva
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | edinburgh of the seven seas
# Processing Record 34 of Set 1 | luderitz
# Processing Record 35 of Set 1 | tongouson
# Processing Record 36 of Set 1 | portland
# Processing Record 37 of Set 1 | mejit
# Processing Record 38 of Set 1 | grytviken
# Processing Record 39 of Set 1 | chibougamau
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | ust-nera
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | gobabis
# Processing Record 44 of Set 1 | margaret river
# Processing Record 45 of Set 1 | isafjordur
# Processing Record 46 of Set 1 | olonkinbyen
# Processing Record 47 of Set 1 | yuzhno-kurilsk
# Processing Record 48 of Set 1 | constantia
# Processing Record 49 of Set 1 | balakhta
# Processing Record 50 of Set 1 | zag
# Processing Record 0 of Set 2 | champerico
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | jatiroto
# Processing Record 4 of Set 2 | los frentones
# Processing Record 5 of Set 2 | kropachevo
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | blackmans bay
# Processing Record 8 of Set 2 | fisterra
# Processing Record 9 of Set 2 | caleta de carquin
# Processing Record 10 of Set 2 | igarka
# Processing Record 11 of Set 2 | vorgashor
# Processing Record 12 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | lhokseumawe
# Processing Record 17 of Set 2 | katsuura
# Processing Record 18 of Set 2 | chonchi
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | buka
# Processing Record 21 of Set 2 | enewetak
# Processing Record 22 of Set 2 | waegwan
# Processing Record 23 of Set 2 | tadine
# Processing Record 24 of Set 2 | castelbuono
# Processing Record 25 of Set 2 | poronaysk
# Processing Record 26 of Set 2 | miranda de ebro
# Processing Record 27 of Set 2 | colonia
# Processing Record 28 of Set 2 | udachny
# Processing Record 29 of Set 2 | qaqortoq
# Processing Record 30 of Set 2 | west island
# Processing Record 31 of Set 2 | waitangi
# Processing Record 32 of Set 2 | hawaiian paradise park
# Processing Record 33 of Set 2 | bhinmal
# Processing Record 34 of Set 2 | gilgit
# Processing Record 35 of Set 2 | nueva palestina
# Processing Record 36 of Set 2 | escanaba
# Processing Record 37 of Set 2 | ushuaia
# Processing Record 38 of Set 2 | fort bragg
# Processing Record 39 of Set 2 | touros
# Processing Record 40 of Set 2 | invercargill
# Processing Record 41 of Set 2 | terbanggi besar
# Processing Record 42 of Set 2 | fiambala
# Processing Record 43 of Set 2 | klyuchi
# Processing Record 44 of Set 2 | konstantinovka
# Processing Record 45 of Set 2 | igreja
# Processing Record 46 of Set 2 | salekhard
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | mount pearl
# Processing Record 49 of Set 2 | berdigestyakh
# Processing Record 0 of Set 3 | lebu
# Processing Record 1 of Set 3 | priob'ye
# Processing Record 2 of Set 3 | sitka
# Processing Record 3 of Set 3 | ust'-ilimsk
# Processing Record 4 of Set 3 | saipan
# Processing Record 5 of Set 3 | praia da vitoria
# Processing Record 6 of Set 3 | aasiaat
# Processing Record 7 of Set 3 | harar
# Processing Record 8 of Set 3 | odienne
# Processing Record 9 of Set 3 | college
# Processing Record 10 of Set 3 | faya-largeau
# Processing Record 11 of Set 3 | badger
# Processing Record 12 of Set 3 | coquimbo
# Processing Record 13 of Set 3 | nobeoka
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | uturoa
# Processing Record 16 of Set 3 | hobyo
# Processing Record 17 of Set 3 | kununurra
# Processing Record 18 of Set 3 | vadso
# Processing Record 19 of Set 3 | hodmezovasarhely
# Processing Record 20 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 21 of Set 3 | francistown
# Processing Record 22 of Set 3 | lethem
# Processing Record 23 of Set 3 | thunder bay
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | aykhal
# Processing Record 26 of Set 3 | mudgee
# Processing Record 27 of Set 3 | baturaja
# Processing Record 28 of Set 3 | marco
# Processing Record 29 of Set 3 | taoudenni
# Processing Record 30 of Set 3 | kayar
# Processing Record 31 of Set 3 | whitehorse
# Processing Record 32 of Set 3 | ariquemes
# Processing Record 33 of Set 3 | nsanje
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | bemidji
# Processing Record 36 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 37 of Set 3 | port saint john's
# Processing Record 38 of Set 3 | kone
# Processing Record 39 of Set 3 | fortuna foothills
# Processing Record 40 of Set 3 | venado tuerto
# Processing Record 41 of Set 3 | happy valley-goose bay
# Processing Record 42 of Set 3 | mossel bay
# Processing Record 43 of Set 3 | kourou
# Processing Record 44 of Set 3 | marsa alam
# Processing Record 45 of Set 3 | baja
# Processing Record 46 of Set 3 | coahuayana de hidalgo
# Processing Record 47 of Set 3 | qamdo
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | villa ojo de agua
# Processing Record 0 of Set 4 | longyearbyen
# Processing Record 1 of Set 4 | beidao
# Processing Record 2 of Set 4 | la'ie
# Processing Record 3 of Set 4 | moroto
# Processing Record 4 of Set 4 | utrik
# Processing Record 5 of Set 4 | kremenets
# Processing Record 6 of Set 4 | nyala
# Processing Record 7 of Set 4 | port douglas
# Processing Record 8 of Set 4 | karratha
# Processing Record 9 of Set 4 | belogorsk
# Processing Record 10 of Set 4 | minas de marcona
# Processing Record 11 of Set 4 | san antonio de pale
# Processing Record 12 of Set 4 | atasu
# Processing Record 13 of Set 4 | kapa'a
# Processing Record 14 of Set 4 | kemi
# Processing Record 15 of Set 4 | longboat key
# Processing Record 16 of Set 4 | yangor
# City not found. Skipping...
# Processing Record 17 of Set 4 | lauro de freitas
# Processing Record 18 of Set 4 | khandyga
# Processing Record 19 of Set 4 | itoman
# Processing Record 20 of Set 4 | pandan
# Processing Record 21 of Set 4 | fortaleza
# Processing Record 22 of Set 4 | lompoc
# Processing Record 23 of Set 4 | freetown
# Processing Record 24 of Set 4 | praia
# Processing Record 25 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 26 of Set 4 | nemuro
# Processing Record 27 of Set 4 | boyolangu
# Processing Record 28 of Set 4 | santa ana jilotzingo
# Processing Record 29 of Set 4 | brokopondo
# Processing Record 30 of Set 4 | ba
# City not found. Skipping...
# Processing Record 31 of Set 4 | redencao
# Processing Record 32 of Set 4 | wewak
# Processing Record 33 of Set 4 | prado
# Processing Record 34 of Set 4 | la passe
# Processing Record 35 of Set 4 | mata-utu
# Processing Record 36 of Set 4 | abepura
# Processing Record 37 of Set 4 | puerto ayora
# Processing Record 38 of Set 4 | mao
# Processing Record 39 of Set 4 | paita
# Processing Record 40 of Set 4 | gizo
# Processing Record 41 of Set 4 | gisborne
# Processing Record 42 of Set 4 | antofagasta
# Processing Record 43 of Set 4 | juegang
# Processing Record 44 of Set 4 | tsiombe
# Processing Record 45 of Set 4 | luanda
# Processing Record 46 of Set 4 | mareeba
# Processing Record 47 of Set 4 | gotsucho
# Processing Record 48 of Set 4 | howard springs
# Processing Record 49 of Set 4 | saku
# Processing Record 0 of Set 5 | kasempa
# Processing Record 1 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 2 of Set 5 | vilyuchinsk
# Processing Record 3 of Set 5 | east london
# Processing Record 4 of Set 5 | petauke
# Processing Record 5 of Set 5 | chilecito
# Processing Record 6 of Set 5 | urangan
# Processing Record 7 of Set 5 | liuboml
# Processing Record 8 of Set 5 | nuku'alofa
# Processing Record 9 of Set 5 | roma
# Processing Record 10 of Set 5 | smithers
# Processing Record 11 of Set 5 | bardai
# Processing Record 12 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 13 of Set 5 | nkurenkuru
# City not found. Skipping...
# Processing Record 14 of Set 5 | tchintabaraden
# Processing Record 15 of Set 5 | santa cruz
# Processing Record 16 of Set 5 | vittoria
# Processing Record 17 of Set 5 | talagutong
# Processing Record 18 of Set 5 | arapiraca
# Processing Record 19 of Set 5 | axim
# Processing Record 20 of Set 5 | thames
# Processing Record 21 of Set 5 | namibe
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | kingston
# Processing Record 24 of Set 5 | san luis de la loma
# Processing Record 25 of Set 5 | almazan
# Processing Record 26 of Set 5 | sassandra
# Processing Record 27 of Set 5 | orchard homes
# Processing Record 28 of Set 5 | ulsteinvik
# Processing Record 29 of Set 5 | patacamaya
# Processing Record 30 of Set 5 | andergrove
# Processing Record 31 of Set 5 | tura
# Processing Record 32 of Set 5 | bikenibeu village
# Processing Record 33 of Set 5 | hirara
# Processing Record 34 of Set 5 | punta arenas
# Processing Record 35 of Set 5 | banda aceh
# Processing Record 36 of Set 5 | pyhajarvi
# Processing Record 37 of Set 5 | yulin
# Processing Record 38 of Set 5 | tazovsky
# Processing Record 39 of Set 5 | nova sintra
# Processing Record 40 of Set 5 | siwa oasis
# Processing Record 41 of Set 5 | khash
# Processing Record 42 of Set 5 | callao
# Processing Record 43 of Set 5 | atafu village
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | tabalah
# Processing Record 46 of Set 5 | tokar
# Processing Record 47 of Set 5 | quellon
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | lihue
# Processing Record 0 of Set 6 | berezovyy
# Processing Record 1 of Set 6 | island harbour
# Processing Record 2 of Set 6 | paracuru
# Processing Record 3 of Set 6 | newman
# Processing Record 4 of Set 6 | imperatriz
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | ascencion
# Processing Record 7 of Set 6 | crane
# Processing Record 8 of Set 6 | daru
# Processing Record 9 of Set 6 | larache
# Processing Record 10 of Set 6 | kolonia town
# Processing Record 11 of Set 6 | chalatenango
# Processing Record 12 of Set 6 | karanja
# Processing Record 13 of Set 6 | alofi
# Processing Record 14 of Set 6 | remire-montjoly
# Processing Record 15 of Set 6 | tame
# Processing Record 16 of Set 6 | grande prairie
# Processing Record 17 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 6 | gamba
# Processing Record 19 of Set 6 | tongliao
# Processing Record 20 of Set 6 | qarazhal
# Processing Record 21 of Set 6 | sao jose da coroa grande
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | paripiranga
# Processing Record 24 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 6 | luau
# Processing Record 26 of Set 6 | prince rupert
# Processing Record 27 of Set 6 | carnarvon
# Processing Record 28 of Set 6 | devon
# Processing Record 29 of Set 6 | kotel'nikovo
# Processing Record 30 of Set 6 | usinsk
# Processing Record 31 of Set 6 | saint-philippe
# Processing Record 32 of Set 6 | katabu
# Processing Record 33 of Set 6 | mana
# Processing Record 34 of Set 6 | antsiranana
# Processing Record 35 of Set 6 | sillamae
# Processing Record 36 of Set 6 | lyubinskiy
# Processing Record 37 of Set 6 | vice
# Processing Record 38 of Set 6 | selfoss
# Processing Record 39 of Set 6 | mount isa
# Processing Record 40 of Set 6 | podporozh'ye
# Processing Record 41 of Set 6 | shingu
# Processing Record 42 of Set 6 | salinas de hidalgo
# Processing Record 43 of Set 6 | bukama
# Processing Record 44 of Set 6 | artesia
# Processing Record 45 of Set 6 | nizhneangarsk
# Processing Record 46 of Set 6 | yarmouth
# Processing Record 47 of Set 6 | murun-kuren
# Processing Record 48 of Set 6 | san angelo
# Processing Record 49 of Set 6 | mahina
# Processing Record 0 of Set 7 | argo
# Processing Record 1 of Set 7 | cannonvale
# Processing Record 2 of Set 7 | kattivakkam
# Processing Record 3 of Set 7 | al jawf
# Processing Record 4 of Set 7 | yeppoon
# Processing Record 5 of Set 7 | sao vicente
# Processing Record 6 of Set 7 | ekibastuz
# Processing Record 7 of Set 7 | mirny
# Processing Record 8 of Set 7 | tabas
# Processing Record 9 of Set 7 | margate
# Processing Record 10 of Set 7 | taltal
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | lerwick
# Processing Record 13 of Set 7 | lorengau
# Processing Record 14 of Set 7 | napili-honokowai
# Processing Record 15 of Set 7 | elliot lake
# Processing Record 16 of Set 7 | crockett
# Processing Record 17 of Set 7 | tyazhinskiy
# Processing Record 18 of Set 7 | mount pleasant
# Processing Record 19 of Set 7 | richards bay
# Processing Record 20 of Set 7 | noosa heads
# Processing Record 21 of Set 7 | waingapu
# Processing Record 22 of Set 7 | isle of lewis
# City not found. Skipping...
# Processing Record 23 of Set 7 | chinde
# Processing Record 24 of Set 7 | naugachhia
# Processing Record 25 of Set 7 | kuruman
# Processing Record 26 of Set 7 | morehead
# Processing Record 27 of Set 7 | susuman
# Processing Record 28 of Set 7 | egilsstadir
# Processing Record 29 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 30 of Set 7 | sirte
# Processing Record 31 of Set 7 | kristiansund
# Processing Record 32 of Set 7 | cooper's town
# Processing Record 33 of Set 7 | geraldton
# Processing Record 34 of Set 7 | st. john's
# Processing Record 35 of Set 7 | mountain home
# Processing Record 36 of Set 7 | sao tome
# Processing Record 37 of Set 7 | cole harbour
# Processing Record 38 of Set 7 | new norfolk
# Processing Record 39 of Set 7 | balsas
# Processing Record 40 of Set 7 | sarina
# Processing Record 41 of Set 7 | bandarbeyla
# Processing Record 42 of Set 7 | nikolayevka
# Processing Record 43 of Set 7 | pasni
# Processing Record 44 of Set 7 | boa vista
# Processing Record 45 of Set 7 | stornoway
# Processing Record 46 of Set 7 | nakhon thai
# Processing Record 47 of Set 7 | qingyang
# Processing Record 48 of Set 7 | chegdomyn
# Processing Record 49 of Set 7 | patong
# Processing Record 0 of Set 8 | skovorodino
# Processing Record 1 of Set 8 | zheleznogorsk-ilimskiy
# Processing Record 2 of Set 8 | priozersk
# Processing Record 3 of Set 8 | turan
# Processing Record 4 of Set 8 | saint-pierre
# Processing Record 5 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 8 | les cayes
# Processing Record 7 of Set 8 | vanino
# Processing Record 8 of Set 8 | xuddur
# Processing Record 9 of Set 8 | cruz del eje
# Processing Record 10 of Set 8 | bengkulu
# Processing Record 11 of Set 8 | mar del plata
# Processing Record 12 of Set 8 | flying fish cove
# Processing Record 13 of Set 8 | stantsiya novyy afon
# Processing Record 14 of Set 8 | novodvinsk
# Processing Record 15 of Set 8 | ivdel'
# Processing Record 16 of Set 8 | baldev
# Processing Record 17 of Set 8 | huarmey
# Processing Record 18 of Set 8 | concord
# Processing Record 19 of Set 8 | anadyr
# Processing Record 20 of Set 8 | bay harbor
# Processing Record 21 of Set 8 | avarua
# Processing Record 22 of Set 8 | sinabang
# Processing Record 23 of Set 8 | rio grande
# Processing Record 24 of Set 8 | lionel town
# Processing Record 25 of Set 8 | pontianak
# Processing Record 26 of Set 8 | san fernando de apure
# Processing Record 27 of Set 8 | hays
# Processing Record 28 of Set 8 | homer
# Processing Record 29 of Set 8 | port alfred
# Processing Record 30 of Set 8 | mirnyy
# Processing Record 31 of Set 8 | general ramirez
# Processing Record 32 of Set 8 | mahabe
# City not found. Skipping...
# Processing Record 33 of Set 8 | nouadhibou
# Processing Record 34 of Set 8 | kodinsk
# Processing Record 35 of Set 8 | funafuti
# Processing Record 36 of Set 8 | as sulayyil
# Processing Record 37 of Set 8 | brasilia
# Processing Record 38 of Set 8 | mount gambier
# Processing Record 39 of Set 8 | yichang
# Processing Record 40 of Set 8 | micheldorf in oberosterreich
# City not found. Skipping...
# Processing Record 41 of Set 8 | ilgin
# Processing Record 42 of Set 8 | trelleborg
# Processing Record 43 of Set 8 | bayugan
# Processing Record 44 of Set 8 | harstad
# Processing Record 45 of Set 8 | ugoofaaru
# Processing Record 46 of Set 8 | carutapera
# Processing Record 47 of Set 8 | woodward
# Processing Record 48 of Set 8 | tralee
# Processing Record 49 of Set 8 | barah
# Processing Record 0 of Set 9 | langepas
# Processing Record 1 of Set 9 | chisec
# Processing Record 2 of Set 9 | crucecita
# Processing Record 3 of Set 9 | sonoita
# Processing Record 4 of Set 9 | naze
# Processing Record 5 of Set 9 | haiku-pauwela
# Processing Record 6 of Set 9 | okhotsk
# Processing Record 7 of Set 9 | olyokminsk
# Processing Record 8 of Set 9 | borinskoye
# Processing Record 9 of Set 9 | dhar
# Processing Record 10 of Set 9 | atherton
# Processing Record 11 of Set 9 | chanika
# Processing Record 12 of Set 9 | okha
# Processing Record 13 of Set 9 | brisas de zicatela
# Processing Record 14 of Set 9 | yangjiang
# Processing Record 15 of Set 9 | adigrat
# Processing Record 16 of Set 9 | pisco
# Processing Record 17 of Set 9 | labinsk
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | unai
# Processing Record 20 of Set 9 | joshimath
# Processing Record 21 of Set 9 | flin flon
# Processing Record 22 of Set 9 | nelson bay
# Processing Record 23 of Set 9 | kiunga
# Processing Record 24 of Set 9 | inhambane
# Processing Record 25 of Set 9 | murzuq
# Processing Record 26 of Set 9 | campoverde
# Processing Record 27 of Set 9 | oranjemund
# Processing Record 28 of Set 9 | balabac
# Processing Record 29 of Set 9 | meulaboh
# Processing Record 30 of Set 9 | upington
# Processing Record 31 of Set 9 | san jose del cabo
# Processing Record 32 of Set 9 | tanrake village
# City not found. Skipping...
# Processing Record 33 of Set 9 | chake chake
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | menzelinsk
# Processing Record 36 of Set 9 | quang ngai
# Processing Record 37 of Set 9 | banlung
# Processing Record 38 of Set 9 | wynyard
# Processing Record 39 of Set 9 | turkmenbasy
# Processing Record 40 of Set 9 | nizhneudinsk
# Processing Record 41 of Set 9 | lugu
# Processing Record 42 of Set 9 | saint johnsbury
# Processing Record 43 of Set 9 | levuka
# Processing Record 44 of Set 9 | kolonia
# Processing Record 45 of Set 9 | brundall
# Processing Record 46 of Set 9 | nizhnyaya tavda
# Processing Record 47 of Set 9 | cherlak
# Processing Record 48 of Set 9 | nizhnesortymskiy
# Processing Record 49 of Set 9 | yasnyy
# Processing Record 0 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 1 of Set 10 | pirallahi
# Processing Record 2 of Set 10 | ar rutbah
# Processing Record 3 of Set 10 | chokwe
# Processing Record 4 of Set 10 | hotan
# Processing Record 5 of Set 10 | apahida
# Processing Record 6 of Set 10 | alice springs
# Processing Record 7 of Set 10 | manta
# Processing Record 8 of Set 10 | namtsy
# Processing Record 9 of Set 10 | cortina d'ampezzo
# Processing Record 10 of Set 10 | kerikeri
# Processing Record 11 of Set 10 | afaahiti
# Processing Record 12 of Set 10 | vuktyl
# Processing Record 13 of Set 10 | sangkhla buri
# Processing Record 14 of Set 10 | walvis bay
# Processing Record 15 of Set 10 | arno
# Processing Record 16 of Set 10 | choibalsan
# Processing Record 17 of Set 10 | ikalamavony
# Processing Record 18 of Set 10 | jalai nur
# Processing Record 19 of Set 10 | roswell
# Processing Record 20 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 21 of Set 10 | nelson
# Processing Record 22 of Set 10 | lianzhou
# Processing Record 23 of Set 10 | ola
# Processing Record 24 of Set 10 | andovoranto
# Processing Record 25 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 26 of Set 10 | gadzhiyevo
# Processing Record 27 of Set 10 | dalandzadgad
# Processing Record 28 of Set 10 | port lincoln
# Processing Record 29 of Set 10 | hadibu
# Processing Record 30 of Set 10 | tromso
# Processing Record 31 of Set 10 | alesund
# Processing Record 32 of Set 10 | basco
# Processing Record 33 of Set 10 | mukalla
# Processing Record 34 of Set 10 | bonthe
# Processing Record 35 of Set 10 | yarkovo
# Processing Record 36 of Set 10 | simpang
# Processing Record 37 of Set 10 | sahagun
# Processing Record 38 of Set 10 | barcelos
# Processing Record 39 of Set 10 | plonsk
# Processing Record 40 of Set 10 | labytnangi
# Processing Record 41 of Set 10 | fort st. john
# Processing Record 42 of Set 10 | benito juarez
# Processing Record 43 of Set 10 | bamboo flat
# Processing Record 44 of Set 10 | dondo
# Processing Record 45 of Set 10 | horta
# Processing Record 46 of Set 10 | kotel'nich
# Processing Record 47 of Set 10 | brookings
# Processing Record 48 of Set 10 | urumqi
# Processing Record 49 of Set 10 | dudinka
# Processing Record 0 of Set 11 | sorong
# Processing Record 1 of Set 11 | umm kaddadah
# Processing Record 2 of Set 11 | hadim
# Processing Record 3 of Set 11 | alaghsas
# Processing Record 4 of Set 11 | prievidza
# Processing Record 5 of Set 11 | luquillo
# Processing Record 6 of Set 11 | toamasina
# Processing Record 7 of Set 11 | toliara
# Processing Record 8 of Set 11 | la cruz
# Processing Record 9 of Set 11 | viedma
# Processing Record 10 of Set 11 | twentynine palms
# Processing Record 11 of Set 11 | duffel
# Processing Record 12 of Set 11 | jatai
# Processing Record 13 of Set 11 | posse
# Processing Record 14 of Set 11 | hovd
# Processing Record 15 of Set 11 | tranby
# Processing Record 16 of Set 11 | kainantu
# Processing Record 17 of Set 11 | kingscliff
# Processing Record 18 of Set 11 | zarzis
# Processing Record 19 of Set 11 | pasighat
# Processing Record 20 of Set 11 | lembar
# City not found. Skipping...
# Processing Record 21 of Set 11 | caconda
# Processing Record 22 of Set 11 | huadian
# Processing Record 23 of Set 11 | motygino
# Processing Record 24 of Set 11 | winston
# Processing Record 25 of Set 11 | wodonga
# Processing Record 26 of Set 11 | dunedin
# Processing Record 27 of Set 11 | arys
# Processing Record 28 of Set 11 | shimanovsk
# Processing Record 29 of Set 11 | chos malal
# Processing Record 30 of Set 11 | pariaman
# Processing Record 31 of Set 11 | alpena
# Processing Record 32 of Set 11 | george town
# Processing Record 33 of Set 11 | sandur
# Processing Record 34 of Set 11 | gevrai
# Processing Record 35 of Set 11 | kitui
# Processing Record 36 of Set 11 | preston
# Processing Record 37 of Set 11 | gua musang
# Processing Record 38 of Set 11 | sur
# Processing Record 39 of Set 11 | villa gesell
# Processing Record 40 of Set 11 | alfredton
# Processing Record 41 of Set 11 | el calafate
# Processing Record 42 of Set 11 | nicoya
# Processing Record 43 of Set 11 | peniche
# Processing Record 44 of Set 11 | tarko-sale
# Processing Record 45 of Set 11 | makaha
# Processing Record 46 of Set 11 | weyburn
# Processing Record 47 of Set 11 | tan-tan
# Processing Record 48 of Set 11 | greenville
# Processing Record 49 of Set 11 | tarauaca
# Processing Record 0 of Set 12 | kupang
# Processing Record 1 of Set 12 | dori
# Processing Record 2 of Set 12 | khanty-mansiysk
# Processing Record 3 of Set 12 | laguna
# Processing Record 4 of Set 12 | kittila
# Processing Record 5 of Set 12 | arkhangel'sk
# Processing Record 6 of Set 12 | labuan
# Processing Record 7 of Set 12 | auce
# Processing Record 8 of Set 12 | isangel
# Processing Record 9 of Set 12 | gassol
# Processing Record 10 of Set 12 | marbella
# Processing Record 11 of Set 12 | sabang
# Processing Record 12 of Set 12 | birao
# Processing Record 13 of Set 12 | butha-buthe
# Processing Record 14 of Set 12 | xinyuan
# Processing Record 15 of Set 12 | maceio
# Processing Record 16 of Set 12 | lerici
# Processing Record 17 of Set 12 | maintirano
# Processing Record 18 of Set 12 | sanctuary point
# Processing Record 19 of Set 12 | darwin
# Processing Record 20 of Set 12 | hasaki
# Processing Record 21 of Set 12 | grand falls-windsor
# Processing Record 22 of Set 12 | kyadabek
# Processing Record 23 of Set 12 | krasnozerskoye
# Processing Record 24 of Set 12 | kouvola
# Processing Record 25 of Set 12 | san bernardo
# Processing Record 26 of Set 12 | tashtagol
# Processing Record 27 of Set 12 | sandnessjoen
# Processing Record 28 of Set 12 | kill devil hills
# Processing Record 29 of Set 12 | nadi
# Processing Record 30 of Set 12 | griffith
# Processing Record 31 of Set 12 | bossangoa
# Processing Record 32 of Set 12 | sint michiel liber
# Processing Record 33 of Set 12 | piui
# Processing Record 34 of Set 12 | tibati
# Processing Record 35 of Set 12 | qionghai
# Processing Record 36 of Set 12 | zemetchino
# Processing Record 37 of Set 12 | antalaha
# Processing Record 38 of Set 12 | harper
# Processing Record 39 of Set 12 | qorovulbozor
# Processing Record 40 of Set 12 | santa ana
# Processing Record 41 of Set 12 | akureyri
# Processing Record 42 of Set 12 | reyhanli
# Processing Record 43 of Set 12 | paredon
# Processing Record 44 of Set 12 | ta`u
# Processing Record 45 of Set 12 | marsabit
# Processing Record 46 of Set 12 | glendive
# Processing Record 47 of Set 12 | puerto aysen
# Processing Record 48 of Set 12 | ingeniero jacobacci
# Processing Record 49 of Set 12 | holualoa
# Processing Record 0 of Set 13 | bathurst
# Processing Record 1 of Set 13 | as samawah
# Processing Record 2 of Set 13 | bals
# Processing Record 3 of Set 13 | weno
# Processing Record 4 of Set 13 | minas de matahambre
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df['Max Temp'] = city_data_df['Max Temp']/10
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port hedland -20.3167  118.5667    30.518        20          12
# 1     papatowai -46.5619  169.4708    28.982        65         100
# 2       iqaluit  63.7506  -68.5145    27.000        79         100
# 3    bredasdorp -34.5322   20.0403    28.838        96         100
# 4      zalingei  12.9096   23.4741    29.921        14           6
#
#    Wind Speed Country        Date
# 0        9.77      AU  1713927646
# 1        1.59      NZ  1713927648
# 2        2.06      CA  1713927648
# 3        0.38      ZA  1713927651
# 4        2.03      SD  1713927651

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port hedland -20.3167  118.5667    30.518        20          12
# 1           papatowai -46.5619  169.4708    28.982        65         100
# 2             iqaluit  63.7506  -68.5145    27.000        79         100
# 3          bredasdorp -34.5322   20.0403    28.838        96         100
# 4            zalingei  12.9096   23.4741    29.921        14           6
#
#          Wind Speed Country        Date
# City_ID
# 0              9.77      AU  1713927646
# 1              1.59      NZ  1713927648
# 2              2.06      CA  1713927648
# 3              0.38      ZA  1713927651
# 4              2.03      SD  1713927651

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors= 'black')
ax.set_title('City Max Latitude vs Temperature')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temperature')
ax.grid(visible = True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors= 'black')
ax.set_title('City Latitude vs Humidity')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.grid(visible = True)



# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors= 'black')
ax.set_title('City Latitude vs Cloudiness')
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.grid(visible = True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors= 'black')
ax.set_title('City Latitude vs Wind Speed')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (m/s)')
ax.grid(visible = True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_data, y_data, x_label, y_label, title):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)
    
    # Calculate the regression line
    regression_line = slope * x_data + intercept
    
    # Plot the data points
    plt.scatter(x_data, y_data, color='blue', alpha=0.5)
    
    # Plot the regression line
    plt.plot(x_data, regression_line, color='red')
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Add text box with regression equation and r-value
    equation_text = f'y={slope:.2f}x + {intercept:.2f}\nR-value: {r_value:.2f}'
    plt.text(0.05, 0.5, equation_text, transform=plt.gca().transAxes, fontsize=10,
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
    
    # Show plot
    plt.grid(True)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2              iqaluit  63.7506 -68.5145    27.000        79         100
# 4             zalingei  12.9096  23.4741    29.921        14           6
# 8              stanley  54.8680  -1.6985    27.719        77          75
# 10       mermoz boabab  14.7065 -17.4758    29.346        85           9
# 11           iskateley  67.6803  53.1512    25.983        84          11
#
#          Wind Speed Country        Date
# City_ID
# 2              2.06      CA  1713927648
# 4              2.03      SD  1713927651
# 8              3.09      GB  1713927377
# 10             5.87      SN  1713927655
# 11             3.58      RU  1713927551

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port hedland -20.3167  118.5667    30.518        20          12
# 1           papatowai -46.5619  169.4708    28.982        65         100
# 3          bredasdorp -34.5322   20.0403    28.838        96         100
# 5           adamstown -25.0660 -130.1015    29.617        85         100
# 6               ancud -41.8697  -73.8203    28.310        82         100
#
#          Wind Speed Country        Date
# City_ID
# 0              9.77      AU  1713927646
# 1              1.59      NZ  1713927648
# 3              0.38      ZA  1713927651
# 5              9.97      PN  1713927572
# 6              3.29      CL  1713927617

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Max Temp']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Norhtern Hemisphere: City Latitude vs. Max Temp'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Linear regression on Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Max Temp']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Max Temp'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** It seems as thought there is a positive correlation between Latitude and Maximum Temperature in the southern hemisphere, meaning that as the latitude increases, the temperature also increases. There is a negative correlation between Latitude and Maximum Temperature in the Northern hemisphere, meaning that as the latitude increases, the temperature decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Humidity']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Norhtern Hemisphere: City Latitude vs. Humidity'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Humidity']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Humidity'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** For both the northern and southern hemispheres, there seems to be no strong correlations between latitude and longitude. The r-values are not very strong.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Cloudiness']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Northern Hemisphere: City Latitude vs. Cloudiness'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Cloudiness']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Cloudiness'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** Similar to the linear relationships between Latitude and Humidity, the linear relationship between latitude and cloudiness also do not seem to be significant or strongly correlated.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Wind Speed']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Northern Hemisphere: City Latitude vs. Wind Speed'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Wind Speed']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Wind Speed'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** Since the r-value for both the linear regressions for the Southern Hemisphere and Northern Hemisphere are close to 0, there seems to be no strong correlation between city latitude and wind speed.
