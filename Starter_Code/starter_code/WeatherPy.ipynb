# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + f'q={city}&appid={weather_api_key}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | vung tau
# Processing Record 3 of Set 1 | invercargill
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | klyuchi
# Processing Record 6 of Set 1 | mossel bay
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | mirnyy
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | enewetak
# Processing Record 13 of Set 1 | manado
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | wailua homesteads
# Processing Record 18 of Set 1 | celestun
# Processing Record 19 of Set 1 | prado
# Processing Record 20 of Set 1 | akureyri
# Processing Record 21 of Set 1 | three points
# Processing Record 22 of Set 1 | zango
# Processing Record 23 of Set 1 | nova vicosa
# Processing Record 24 of Set 1 | tralee
# Processing Record 25 of Set 1 | papao
# Processing Record 26 of Set 1 | howard springs
# Processing Record 27 of Set 1 | los andes
# Processing Record 28 of Set 1 | tura
# Processing Record 29 of Set 1 | tejen
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | pandan
# Processing Record 32 of Set 1 | mary
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | leninskoye
# Processing Record 36 of Set 1 | ulladulla
# Processing Record 37 of Set 1 | asau
# Processing Record 38 of Set 1 | papatowai
# Processing Record 39 of Set 1 | mana
# Processing Record 40 of Set 1 | santa cruz
# Processing Record 41 of Set 1 | leh
# Processing Record 42 of Set 1 | blackmans bay
# Processing Record 43 of Set 1 | abong mbang
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | uturoa
# Processing Record 46 of Set 1 | benguela
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | pitimbu
# Processing Record 49 of Set 1 | pajara
# Processing Record 50 of Set 1 | puerto baquerizo moreno
# Processing Record 0 of Set 2 | jiaojiang
# Processing Record 1 of Set 2 | vangaindrano
# Processing Record 2 of Set 2 | bontang
# Processing Record 3 of Set 2 | malampaka
# Processing Record 4 of Set 2 | prince rupert
# Processing Record 5 of Set 2 | isafjordur
# Processing Record 6 of Set 2 | nar'yan-mar
# Processing Record 7 of Set 2 | hawaiian paradise park
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | kristiansund
# Processing Record 10 of Set 2 | la mira
# Processing Record 11 of Set 2 | badger
# Processing Record 12 of Set 2 | cambuga
# Processing Record 13 of Set 2 | christchurch
# Processing Record 14 of Set 2 | fort bragg
# Processing Record 15 of Set 2 | sao jose da coroa grande
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | stanley
# Processing Record 18 of Set 2 | keflavik
# Processing Record 19 of Set 2 | jianshui
# Processing Record 20 of Set 2 | chul'man
# Processing Record 21 of Set 2 | khandyga
# Processing Record 22 of Set 2 | port hedland
# Processing Record 23 of Set 2 | tarakan
# Processing Record 24 of Set 2 | flying fish cove
# Processing Record 25 of Set 2 | chilecito
# Processing Record 26 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 27 of Set 2 | chakradharpur
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | iskateley
# Processing Record 30 of Set 2 | xacmaz
# Processing Record 31 of Set 2 | namtsy
# Processing Record 32 of Set 2 | herval
# Processing Record 33 of Set 2 | jackson
# Processing Record 34 of Set 2 | bataipora
# Processing Record 35 of Set 2 | vanino
# Processing Record 36 of Set 2 | margaret river
# Processing Record 37 of Set 2 | urzhum
# Processing Record 38 of Set 2 | rongelap
# Processing Record 39 of Set 2 | toliara
# Processing Record 40 of Set 2 | gadzhiyevo
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | puerto leguizamo
# Processing Record 43 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 44 of Set 2 | port mathurin
# Processing Record 45 of Set 2 | brisas de zicatela
# Processing Record 46 of Set 2 | noshiro
# Processing Record 47 of Set 2 | puerto armuelles
# Processing Record 48 of Set 2 | chany
# Processing Record 49 of Set 2 | kananga
# Processing Record 0 of Set 3 | mansa
# Processing Record 1 of Set 3 | djambala
# Processing Record 2 of Set 3 | saipan
# Processing Record 3 of Set 3 | mejit
# Processing Record 4 of Set 3 | cidade velha
# Processing Record 5 of Set 3 | saint-pierre
# Processing Record 6 of Set 3 | ayame
# Processing Record 7 of Set 3 | khanpur mahar
# Processing Record 8 of Set 3 | aasiaat
# Processing Record 9 of Set 3 | manggar
# Processing Record 10 of Set 3 | berezovo
# Processing Record 11 of Set 3 | bafra
# Processing Record 12 of Set 3 | bilibino
# Processing Record 13 of Set 3 | xinqing
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | morehead city
# Processing Record 16 of Set 3 | roma
# Processing Record 17 of Set 3 | kingston
# Processing Record 18 of Set 3 | kozloduy
# Processing Record 19 of Set 3 | saratamata
# City not found. Skipping...
# Processing Record 20 of Set 3 | atafu village
# Processing Record 21 of Set 3 | haiku-pauwela
# Processing Record 22 of Set 3 | saucillo
# Processing Record 23 of Set 3 | port douglas
# Processing Record 24 of Set 3 | bardai
# Processing Record 25 of Set 3 | challapata
# Processing Record 26 of Set 3 | iradan
# City not found. Skipping...
# Processing Record 27 of Set 3 | chonchi
# Processing Record 28 of Set 3 | vorgashor
# Processing Record 29 of Set 3 | monticello
# Processing Record 30 of Set 3 | ust-nera
# Processing Record 31 of Set 3 | vanimo
# Processing Record 32 of Set 3 | thinadhoo
# Processing Record 33 of Set 3 | peebles
# Processing Record 34 of Set 3 | bandarbeyla
# Processing Record 35 of Set 3 | al wakrah
# Processing Record 36 of Set 3 | rawson
# Processing Record 37 of Set 3 | olonkinbyen
# Processing Record 38 of Set 3 | malvan
# Processing Record 39 of Set 3 | pueblo west
# Processing Record 40 of Set 3 | kargopol'
# Processing Record 41 of Set 3 | west island
# Processing Record 42 of Set 3 | vicuna
# Processing Record 43 of Set 3 | shannon
# Processing Record 44 of Set 3 | college
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | barah
# Processing Record 47 of Set 3 | novopavlovsk
# Processing Record 48 of Set 3 | codrington
# Processing Record 49 of Set 3 | anadyr
# Processing Record 0 of Set 4 | tughyl
# Processing Record 1 of Set 4 | deogarh
# Processing Record 2 of Set 4 | coxen hole
# Processing Record 3 of Set 4 | rockwood
# Processing Record 4 of Set 4 | mukah
# City not found. Skipping...
# Processing Record 5 of Set 4 | tutoia
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | griffith
# Processing Record 8 of Set 4 | shantobe
# Processing Record 9 of Set 4 | nova xavantina
# Processing Record 10 of Set 4 | polyarnyy
# Processing Record 11 of Set 4 | antofagasta
# Processing Record 12 of Set 4 | haimen
# Processing Record 13 of Set 4 | udachny
# Processing Record 14 of Set 4 | mozarlandia
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | al bawiti
# Processing Record 17 of Set 4 | tiksi
# Processing Record 18 of Set 4 | hami
# Processing Record 19 of Set 4 | kumeny
# Processing Record 20 of Set 4 | kapa'a
# Processing Record 21 of Set 4 | punta arenas
# Processing Record 22 of Set 4 | talnakh
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | tual
# Processing Record 25 of Set 4 | golpazari
# Processing Record 26 of Set 4 | kirovskiy
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | ciro marina
# Processing Record 29 of Set 4 | walvis bay
# Processing Record 30 of Set 4 | cill airne
# Processing Record 31 of Set 4 | alaghsas
# Processing Record 32 of Set 4 | quellon
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | kerikeri
# Processing Record 35 of Set 4 | timimoun
# Processing Record 36 of Set 4 | oyama
# Processing Record 37 of Set 4 | portland
# Processing Record 38 of Set 4 | sidhi
# Processing Record 39 of Set 4 | kone
# Processing Record 40 of Set 4 | retreat
# Processing Record 41 of Set 4 | blythe
# Processing Record 42 of Set 4 | tobruk
# Processing Record 43 of Set 4 | colares
# Processing Record 44 of Set 4 | mount gambier
# Processing Record 45 of Set 4 | hadibu
# Processing Record 46 of Set 4 | wafangdian
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | kamaishi
# Processing Record 49 of Set 4 | lebu
# Processing Record 0 of Set 5 | fruita
# Processing Record 1 of Set 5 | ibi
# Processing Record 2 of Set 5 | tippi
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | sao joao da barra
# Processing Record 5 of Set 5 | porto novo
# Processing Record 6 of Set 5 | tsiombe
# Processing Record 7 of Set 5 | beidao
# Processing Record 8 of Set 5 | salekhard
# Processing Record 9 of Set 5 | pante makasar
# City not found. Skipping...
# Processing Record 10 of Set 5 | puerto penasco
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | buurhakaba
# Processing Record 13 of Set 5 | tokar
# Processing Record 14 of Set 5 | pangody
# Processing Record 15 of Set 5 | midvagur
# Processing Record 16 of Set 5 | enguera
# Processing Record 17 of Set 5 | kuanda
# Processing Record 18 of Set 5 | yorkton
# Processing Record 19 of Set 5 | buka
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | sao mateus do sul
# Processing Record 22 of Set 5 | ciudad bolivar
# Processing Record 23 of Set 5 | ola
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | wanganui
# Processing Record 26 of Set 5 | aitape
# Processing Record 27 of Set 5 | naze
# Processing Record 28 of Set 5 | hood river
# Processing Record 29 of Set 5 | nemuro
# Processing Record 30 of Set 5 | abashiri
# Processing Record 31 of Set 5 | iguape
# Processing Record 32 of Set 5 | la passe
# Processing Record 33 of Set 5 | vicam
# Processing Record 34 of Set 5 | berdigestyakh
# Processing Record 35 of Set 5 | campo gallo
# Processing Record 36 of Set 5 | jumla
# Processing Record 37 of Set 5 | midleton
# Processing Record 38 of Set 5 | kenora
# Processing Record 39 of Set 5 | mohr
# Processing Record 40 of Set 5 | meadow lakes
# Processing Record 41 of Set 5 | prince george
# Processing Record 42 of Set 5 | afaahiti
# Processing Record 43 of Set 5 | egilsstadir
# Processing Record 44 of Set 5 | port lincoln
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | malindi
# Processing Record 47 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 5 | gisborne
# Processing Record 49 of Set 5 | taltal
# Processing Record 0 of Set 6 | le port
# Processing Record 1 of Set 6 | mount pearl
# Processing Record 2 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 6 | lompoc
# Processing Record 4 of Set 6 | lautoka
# Processing Record 5 of Set 6 | xilin hot
# Processing Record 6 of Set 6 | port elizabeth
# Processing Record 7 of Set 6 | fort mcmurray
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | alvorada
# Processing Record 10 of Set 6 | sinjar
# Processing Record 11 of Set 6 | north battleford
# Processing Record 12 of Set 6 | tolanaro
# Processing Record 13 of Set 6 | lufilufi
# Processing Record 14 of Set 6 | sabzevar
# Processing Record 15 of Set 6 | natal
# Processing Record 16 of Set 6 | bargara
# City not found. Skipping...
# Processing Record 17 of Set 6 | charters towers
# Processing Record 18 of Set 6 | san patricio
# Processing Record 19 of Set 6 | makoua
# Processing Record 20 of Set 6 | minas de marcona
# Processing Record 21 of Set 6 | embarcacion
# Processing Record 22 of Set 6 | martapura
# Processing Record 23 of Set 6 | nueva gerona
# Processing Record 24 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 25 of Set 6 | praia da vitoria
# Processing Record 26 of Set 6 | baruun-urt
# Processing Record 27 of Set 6 | crane
# Processing Record 28 of Set 6 | axim
# Processing Record 29 of Set 6 | newman
# Processing Record 30 of Set 6 | susuman
# Processing Record 31 of Set 6 | kodiak
# Processing Record 32 of Set 6 | port saint john's
# Processing Record 33 of Set 6 | dudinka
# Processing Record 34 of Set 6 | araguaina
# Processing Record 35 of Set 6 | constantia
# Processing Record 36 of Set 6 | alcarras
# Processing Record 37 of Set 6 | baraki barak
# Processing Record 38 of Set 6 | am timan
# Processing Record 39 of Set 6 | muromtsevo
# Processing Record 40 of Set 6 | oltinko'l
# Processing Record 41 of Set 6 | rio verde de mato grosso
# Processing Record 42 of Set 6 | ocean pointe
# City not found. Skipping...
# Processing Record 43 of Set 6 | ussuriysk
# Processing Record 44 of Set 6 | yelizovo
# Processing Record 45 of Set 6 | moapa valley
# Processing Record 46 of Set 6 | chimoio
# Processing Record 47 of Set 6 | trairi
# Processing Record 48 of Set 6 | beltran
# Processing Record 49 of Set 6 | twentynine palms
# Processing Record 0 of Set 7 | chandpur
# Processing Record 1 of Set 7 | malango
# Processing Record 2 of Set 7 | maun
# Processing Record 3 of Set 7 | port blair
# Processing Record 4 of Set 7 | ashburton
# Processing Record 5 of Set 7 | adzope
# Processing Record 6 of Set 7 | salalah
# Processing Record 7 of Set 7 | lihue
# Processing Record 8 of Set 7 | chardara
# Processing Record 9 of Set 7 | greenville
# Processing Record 10 of Set 7 | duncan
# Processing Record 11 of Set 7 | westport
# Processing Record 12 of Set 7 | kharp
# Processing Record 13 of Set 7 | vila velha
# Processing Record 14 of Set 7 | lamar
# Processing Record 15 of Set 7 | kavieng
# Processing Record 16 of Set 7 | puerto lempira
# Processing Record 17 of Set 7 | tsengel
# Processing Record 18 of Set 7 | smach mean chey
# City not found. Skipping...
# Processing Record 19 of Set 7 | tommot
# Processing Record 20 of Set 7 | linhares
# Processing Record 21 of Set 7 | marmara ereglisi
# Processing Record 22 of Set 7 | kailua-kona
# Processing Record 23 of Set 7 | weno
# Processing Record 24 of Set 7 | luau
# Processing Record 25 of Set 7 | san
# Processing Record 26 of Set 7 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 27 of Set 7 | taro
# Processing Record 28 of Set 7 | kotabumi
# Processing Record 29 of Set 7 | fort st. john
# Processing Record 30 of Set 7 | san pedro
# Processing Record 31 of Set 7 | grand-fort-philippe
# Processing Record 32 of Set 7 | amherst
# Processing Record 33 of Set 7 | longjing
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | fatsa
# Processing Record 36 of Set 7 | espargos
# City not found. Skipping...
# Processing Record 37 of Set 7 | la'ie
# Processing Record 38 of Set 7 | el rosario
# Processing Record 39 of Set 7 | bonthe
# Processing Record 40 of Set 7 | velizh
# Processing Record 41 of Set 7 | st. john's
# Processing Record 42 of Set 7 | ambon
# Processing Record 43 of Set 7 | palmer
# Processing Record 44 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 7 | kete krachi
# Processing Record 46 of Set 7 | gornozavodsk
# Processing Record 47 of Set 7 | carnarvon
# Processing Record 48 of Set 7 | marsaskala
# City not found. Skipping...
# Processing Record 49 of Set 7 | coquimbo
# Processing Record 0 of Set 8 | mogok
# Processing Record 1 of Set 8 | bubaque
# Processing Record 2 of Set 8 | derzhavinsk
# Processing Record 3 of Set 8 | chibougamau
# Processing Record 4 of Set 8 | whangarei
# Processing Record 5 of Set 8 | taoudenni
# Processing Record 6 of Set 8 | vadso
# Processing Record 7 of Set 8 | terrace
# Processing Record 8 of Set 8 | baud
# Processing Record 9 of Set 8 | el tigre
# Processing Record 10 of Set 8 | salinopolis
# Processing Record 11 of Set 8 | muynoq
# Processing Record 12 of Set 8 | san antonio de pale
# Processing Record 13 of Set 8 | tazovsky
# Processing Record 14 of Set 8 | huedin
# Processing Record 15 of Set 8 | amga
# Processing Record 16 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 8 | santiago
# Processing Record 18 of Set 8 | akonolinga
# Processing Record 19 of Set 8 | melekeok village
# Processing Record 20 of Set 8 | hithadhoo
# Processing Record 21 of Set 8 | hirara
# Processing Record 22 of Set 8 | fisterra
# Processing Record 23 of Set 8 | nova sintra
# Processing Record 24 of Set 8 | kolonia
# Processing Record 25 of Set 8 | cabo san lucas
# Processing Record 26 of Set 8 | road town
# Processing Record 27 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 28 of Set 8 | kununurra
# Processing Record 29 of Set 8 | sungai penuh
# Processing Record 30 of Set 8 | tingi
# Processing Record 31 of Set 8 | la ronge
# Processing Record 32 of Set 8 | hashtrud
# Processing Record 33 of Set 8 | lure
# Processing Record 34 of Set 8 | kenai
# Processing Record 35 of Set 8 | lincheng
# Processing Record 36 of Set 8 | terenozek
# Processing Record 37 of Set 8 | promyshlennaya
# Processing Record 38 of Set 8 | piui
# Processing Record 39 of Set 8 | hotan
# Processing Record 40 of Set 8 | nadi
# Processing Record 41 of Set 8 | ampanihy
# Processing Record 42 of Set 8 | holualoa
# Processing Record 43 of Set 8 | coari
# Processing Record 44 of Set 8 | cruzeiro do sul
# Processing Record 45 of Set 8 | mulayjah
# Processing Record 46 of Set 8 | arno
# Processing Record 47 of Set 8 | loiza
# Processing Record 48 of Set 8 | sant'antioco
# Processing Record 49 of Set 8 | alice springs
# Processing Record 0 of Set 9 | mili
# Processing Record 1 of Set 9 | aswan
# Processing Record 2 of Set 9 | gao
# Processing Record 3 of Set 9 | hassi messaoud
# Processing Record 4 of Set 9 | itoman
# Processing Record 5 of Set 9 | yugorsk
# Processing Record 6 of Set 9 | katsuura
# Processing Record 7 of Set 9 | lisala
# Processing Record 8 of Set 9 | porto barra do ivinheima
# Processing Record 9 of Set 9 | wuchuan
# Processing Record 10 of Set 9 | zhezqazghan
# Processing Record 11 of Set 9 | amursk
# Processing Record 12 of Set 9 | tsivil'sk
# Processing Record 13 of Set 9 | fonadhoo
# City not found. Skipping...
# Processing Record 14 of Set 9 | cockburn town
# Processing Record 15 of Set 9 | arta
# Processing Record 16 of Set 9 | katsuren-haebaru
# Processing Record 17 of Set 9 | vilyuchinsk
# Processing Record 18 of Set 9 | kendari
# Processing Record 19 of Set 9 | sungho 1-tong
# Processing Record 20 of Set 9 | oban
# Processing Record 21 of Set 9 | usinsk
# Processing Record 22 of Set 9 | xifeng
# Processing Record 23 of Set 9 | orkney
# Processing Record 24 of Set 9 | abbeville
# Processing Record 25 of Set 9 | zyryanskoye
# Processing Record 26 of Set 9 | la huacana
# Processing Record 27 of Set 9 | boguchany
# Processing Record 28 of Set 9 | raja
# Processing Record 29 of Set 9 | vernon
# Processing Record 30 of Set 9 | bamboo flat
# Processing Record 31 of Set 9 | forres
# Processing Record 32 of Set 9 | ghat
# Processing Record 33 of Set 9 | klaksvik
# Processing Record 34 of Set 9 | los frentones
# Processing Record 35 of Set 9 | maumere
# Processing Record 36 of Set 9 | miyanoura
# City not found. Skipping...
# Processing Record 37 of Set 9 | beloyarskiy
# Processing Record 38 of Set 9 | ugoofaaru
# Processing Record 39 of Set 9 | severo-yeniseyskiy
# Processing Record 40 of Set 9 | zhigalovo
# Processing Record 41 of Set 9 | zouerate
# Processing Record 42 of Set 9 | consolacion del sur
# Processing Record 43 of Set 9 | banda aceh
# Processing Record 44 of Set 9 | ciudad insurgentes
# Processing Record 45 of Set 9 | piti village
# Processing Record 46 of Set 9 | governor's harbour
# City not found. Skipping...
# Processing Record 47 of Set 9 | smithers
# Processing Record 48 of Set 9 | copala
# Processing Record 49 of Set 9 | tay ninh
# Processing Record 0 of Set 10 | daru
# Processing Record 1 of Set 10 | kabansk
# Processing Record 2 of Set 10 | trenggalek
# Processing Record 3 of Set 10 | grand baie
# Processing Record 4 of Set 10 | markivka
# Processing Record 5 of Set 10 | idfu
# Processing Record 6 of Set 10 | port shepstone
# Processing Record 7 of Set 10 | grajau
# Processing Record 8 of Set 10 | purepero de echaiz
# Processing Record 9 of Set 10 | salinas
# Processing Record 10 of Set 10 | tanki leendert
# City not found. Skipping...
# Processing Record 11 of Set 10 | tavricheskoye
# Processing Record 12 of Set 10 | sisimiut
# Processing Record 13 of Set 10 | tabriz
# Processing Record 14 of Set 10 | talakan
# Processing Record 15 of Set 10 | whitehorse
# Processing Record 16 of Set 10 | dabeiba
# Processing Record 17 of Set 10 | williams lake
# Processing Record 18 of Set 10 | abilene
# Processing Record 19 of Set 10 | urangan
# Processing Record 20 of Set 10 | ripoll
# Processing Record 21 of Set 10 | igarka
# Processing Record 22 of Set 10 | mesyagutovo
# Processing Record 23 of Set 10 | kimberley
# Processing Record 24 of Set 10 | malabar
# Processing Record 25 of Set 10 | labasa
# Processing Record 26 of Set 10 | sitampiky
# City not found. Skipping...
# Processing Record 27 of Set 10 | colonia
# Processing Record 28 of Set 10 | sao paulo de olivenca
# Processing Record 29 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 30 of Set 10 | sao raimundo das mangabeiras
# Processing Record 31 of Set 10 | pueblo nuevo
# Processing Record 32 of Set 10 | pariaman
# Processing Record 33 of Set 10 | tabas
# Processing Record 34 of Set 10 | taroa
# Processing Record 35 of Set 10 | choyr
# Processing Record 36 of Set 10 | gaspe
# Processing Record 37 of Set 10 | sandnessjoen
# Processing Record 38 of Set 10 | bechar
# Processing Record 39 of Set 10 | bikenibeu village
# Processing Record 40 of Set 10 | essaouira
# Processing Record 41 of Set 10 | mount isa
# Processing Record 42 of Set 10 | mochudi
# Processing Record 43 of Set 10 | sola
# Processing Record 44 of Set 10 | skutskar
# City not found. Skipping...
# Processing Record 45 of Set 10 | elverum
# Processing Record 46 of Set 10 | mbanza kongo
# Processing Record 47 of Set 10 | kidal
# Processing Record 48 of Set 10 | lazaro cardenas
# Processing Record 49 of Set 10 | ubari
# Processing Record 0 of Set 11 | north bend
# Processing Record 1 of Set 11 | yuzhno-kurilsk
# Processing Record 2 of Set 11 | taulaga
# Processing Record 3 of Set 11 | mahanoro
# Processing Record 4 of Set 11 | morococha
# Processing Record 5 of Set 11 | callao
# Processing Record 6 of Set 11 | rakops
# Processing Record 7 of Set 11 | freetown
# Processing Record 8 of Set 11 | henderson
# Processing Record 9 of Set 11 | urucui
# Processing Record 10 of Set 11 | natchez
# Processing Record 11 of Set 11 | molepolole
# Processing Record 12 of Set 11 | ta`u
# Processing Record 13 of Set 11 | kirakira
# Processing Record 14 of Set 11 | fortuna
# Processing Record 15 of Set 11 | kawalu
# Processing Record 16 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 17 of Set 11 | glen innes
# Processing Record 18 of Set 11 | laguna
# Processing Record 19 of Set 11 | tofol
# Processing Record 20 of Set 11 | malanville
# Processing Record 21 of Set 11 | indapur
# Processing Record 22 of Set 11 | krasnogorskiy
# Processing Record 23 of Set 11 | varadero
# Processing Record 24 of Set 11 | pisco
# Processing Record 25 of Set 11 | waitara
# Processing Record 26 of Set 11 | shingu
# Processing Record 27 of Set 11 | tulun
# Processing Record 28 of Set 11 | kudahuvadhoo
# Processing Record 29 of Set 11 | nogent-sur-seine
# Processing Record 30 of Set 11 | mabaruma
# Processing Record 31 of Set 11 | cable beach
# City not found. Skipping...
# Processing Record 32 of Set 11 | samamea
# City not found. Skipping...
# Processing Record 33 of Set 11 | hobyo
# Processing Record 34 of Set 11 | beteza
# City not found. Skipping...
# Processing Record 35 of Set 11 | nyagan
# Processing Record 36 of Set 11 | sabang
# Processing Record 37 of Set 11 | taghazout
# Processing Record 38 of Set 11 | sinabang
# Processing Record 39 of Set 11 | nouadhibou
# Processing Record 40 of Set 11 | san pedro pochutla
# Processing Record 41 of Set 11 | kayangel
# Processing Record 42 of Set 11 | padang
# Processing Record 43 of Set 11 | santa ana
# Processing Record 44 of Set 11 | camocim
# Processing Record 45 of Set 11 | at taraf
# Processing Record 46 of Set 11 | morristown
# Processing Record 47 of Set 11 | coyhaique
# Processing Record 48 of Set 11 | campos belos
# Processing Record 49 of Set 11 | argo
# Processing Record 0 of Set 12 | monrovia
# Processing Record 1 of Set 12 | mathba
# Processing Record 2 of Set 12 | touros
# Processing Record 3 of Set 12 | umba
# Processing Record 4 of Set 12 | campo grande
# Processing Record 5 of Set 12 | tabalah
# Processing Record 6 of Set 12 | olgii
# City not found. Skipping...
# Processing Record 7 of Set 12 | tasqala
# Processing Record 8 of Set 12 | banfora
# Processing Record 9 of Set 12 | utrik
# Processing Record 10 of Set 12 | inarajan village
# Processing Record 11 of Set 12 | scarborough
# Processing Record 12 of Set 12 | casablanca
# Processing Record 13 of Set 12 | kachug
# Processing Record 14 of Set 12 | aykhal
# Processing Record 15 of Set 12 | lloydminster
# Processing Record 16 of Set 12 | tanjung selor
# City not found. Skipping...
# Processing Record 17 of Set 12 | karachayevsk
# Processing Record 18 of Set 12 | tazacorte
# Processing Record 19 of Set 12 | makubetsu
# Processing Record 20 of Set 12 | ryotsu-minato
# Processing Record 21 of Set 12 | rikaze
# Processing Record 22 of Set 12 | mont-dore
# Processing Record 23 of Set 12 | fale old settlement
# Processing Record 24 of Set 12 | pimentel
# Processing Record 25 of Set 12 | levuka
# Processing Record 26 of Set 12 | suntar
# Processing Record 27 of Set 12 | queenstown
# Processing Record 28 of Set 12 | bria
# Processing Record 29 of Set 12 | howrah
# Processing Record 30 of Set 12 | notodden
# Processing Record 31 of Set 12 | fortaleza
# Processing Record 32 of Set 12 | shiguai
# Processing Record 33 of Set 12 | lakatoro
# Processing Record 34 of Set 12 | north shore
# Processing Record 35 of Set 12 | xunchang
# Processing Record 36 of Set 12 | udaipur
# Processing Record 37 of Set 12 | sesheke
# Processing Record 38 of Set 12 | ballston spa
# Processing Record 39 of Set 12 | mar del plata
# Processing Record 40 of Set 12 | stornoway
# Processing Record 41 of Set 12 | lubao
# Processing Record 42 of Set 12 | poronaysk
# Processing Record 43 of Set 12 | rio grande
# Processing Record 44 of Set 12 | usogorsk
# Processing Record 45 of Set 12 | happy valley-goose bay
# Processing Record 46 of Set 12 | olyokminsk
# Processing Record 47 of Set 12 | ciudad lazaro cardenas
# Processing Record 48 of Set 12 | watsa
# Processing Record 49 of Set 12 | tondano
# Processing Record 0 of Set 13 | sarmiento
# Processing Record 1 of Set 13 | madan
# Processing Record 2 of Set 13 | inhambane
# Processing Record 3 of Set 13 | juneau
# Processing Record 4 of Set 13 | revelstoke
# Processing Record 5 of Set 13 | altai
# Processing Record 6 of Set 13 | ibipeba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto natales -51.7236  -72.4875    277.31        90         100
# 1        vung tau  10.3460  107.0843    302.56        74          98
# 2    invercargill -46.4000  168.3500    292.60        56         100
# 3          bethel  41.3712  -73.4140    282.79        60         100
# 4         klyuchi  52.2667   79.1667    274.86        50          24
#
#    Wind Speed Country        Date
# 0        2.40      CL  1713922617
# 1        4.77      VN  1713922911
# 2        3.13      NZ  1713922619
# 3        1.34      US  1713922914
# 4        6.24      RU  1713922640

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875    277.31        90         100
# 1              vung tau  10.3460  107.0843    302.56        74          98
# 2          invercargill -46.4000  168.3500    292.60        56         100
# 3                bethel  41.3712  -73.4140    282.79        60         100
# 4               klyuchi  52.2667   79.1667    274.86        50          24
#
#          Wind Speed Country        Date
# City_ID
# 0              2.40      CL  1713922617
# 1              4.77      VN  1713922911
# 2              3.13      NZ  1713922619
# 3              1.34      US  1713922914
# 4              6.24      RU  1713922640

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors= 'black')
ax.set_title('City Max Latitude vs Temperature')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temperature')
ax.grid(visible = True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors= 'black')
ax.set_title('City Latitude vs Humidity')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.grid(visible = True)



# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors= 'black')
ax.set_title('City Latitude vs Cloudiness')
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.grid(visible = True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
fig, ax = plt.subplots()
ax.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors= 'black')
ax.set_title('City Latitude vs Wind Speed')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (m/s)')
ax.grid(visible = True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_data, y_data, x_label, y_label, title):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)
    
    # Calculate the regression line
    regression_line = slope * x_data + intercept
    
    # Plot the data points
    plt.scatter(x_data, y_data, color='blue', alpha=0.5)
    
    # Plot the regression line
    plt.plot(x_data, regression_line, color='red')
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Add text box with regression equation and r-value
    equation_text = f'y={slope:.2f}x + {intercept:.2f}\nR-value: {r_value:.2f}'
    plt.text(0.05, 0.5, equation_text, transform=plt.gca().transAxes, fontsize=10,
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
    
    # Show plot
    plt.grid(True)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        vung tau  10.3460  107.0843    302.56        74          98
# 3          bethel  41.3712  -73.4140    282.79        60         100
# 4         klyuchi  52.2667   79.1667    274.86        50          24
# 9          mirnyy  62.5353  113.9611    272.72        94          92
# 11       enewetak  11.3474  162.3373    300.84        81         100
#
#          Wind Speed Country        Date
# City_ID
# 1              4.77      VN  1713922911
# 3              1.34      US  1713922914
# 4              6.24      RU  1713922640
# 9              3.58      RU  1713922917
# 11             8.37      MH  1713922920

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875    277.31        90         100
# 2          invercargill -46.4000  168.3500    292.60        56         100
# 5            mossel bay -34.1831   22.1460    288.11        93         100
# 6           east london -33.0153   27.9116    294.12        87          75
# 7             grytviken -54.2811  -36.5092    271.00        78          52
#
#          Wind Speed Country        Date
# City_ID
# 0              2.40      CL  1713922617
# 2              3.13      NZ  1713922619
# 5              0.35      ZA  1713922914
# 6              4.10      ZA  1713922914
# 7             10.95      GS  1713922914

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Max Temp']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Norhtern Hemisphere: City Latitude vs. Max Temp'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Linear regression on Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Max Temp']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Max Temp'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** It seems as thought there is a positive correlation between Latitude and Maximum Temperature in the southern hemisphere, meaning that as the latitude increases, the temperature also increases. There is a negative correlation between Latitude and Maximum Temperature in the Northern hemisphere, meaning that as the latitude increases, the temperature decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Humidity']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Norhtern Hemisphere: City Latitude vs. Humidity'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Humidity']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Humidity'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** For both the northern and southern hemispheres, there seems to be no strong correlations between latitude and longitude. The r-values are not very strong.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Cloudiness']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Northern Hemisphere: City Latitude vs. Cloudiness'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Cloudiness']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Cloudiness'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** Similar to the linear relationships between Latitude and Humidity, the linear relationship between latitude and cloudiness also do not seem to be significant or strongly correlated.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_data = northern_hemi_df['Lat']
y_data = northern_hemi_df['Wind Speed']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Northern Hemisphere: City Latitude vs. Wind Speed'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %%
# Southern Hemisphere
x_data = southern_hemi_df['Lat']
y_data = southern_hemi_df['Wind Speed']

#label axes & title
x_label = 'Latitude'
y_label = 'Max Temp'
title = 'Southern Hemisphere: City Latitude vs. Wind Speed'

plot_linear_regression(x_data, y_data, x_label, y_label, title)

# %% [markdown]
# **Discussion about the linear relationship:** Since the r-value for both the linear regressions for the Southern Hemisphere and Northern Hemisphere are close to 0, there seems to be no strong correlation between city latitude and wind speed.
